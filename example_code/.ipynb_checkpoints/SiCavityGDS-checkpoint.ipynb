# %%
# Aaron M. Day
# Harvard Fall '22
# python script using PHIDL for gds layout of 6 cavities optimized for G and T centers in Silicon

from IPython import get_ipython;   
get_ipython().magic('reset -sf')
from phidl import Device
from phidl import quickplot as qp # Rename "quickplot()" to the easier "qp()"
import phidl.geometry as pg
import numpy as np

samples = []

# %%
DIR = '/Users/aaronday/Documents/Python/Research/GDS/SiCavityGDS/'
file_name = 'SiGcenterCavity_design1.gds'

D = Device() #create blank device and add unit cell to it
c = pg.import_gds(DIR+file_name, cellname = None, flatten = False)
qp(c)
ic = pg.invert(c,border=0)
qp(ic)
h = c.ymax-c.ymin
w = c.xmax-c.xmin
#print(h)
#print(w)

c.add_port(name='N', midpoint= [0,h/2], width = w, orientation = 90)
c.add_port(name='S', midpoint= [0,c.ymin], width = w, orientation = 270)
trenchT = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
trenchB = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
c = D << c

c.connect(port = 'N', destination = trenchT.ports['S']) #stack trench-waveguide-trench for unit cell
trenchB.connect(port = 'N', destination = c.ports['S'])

D.center = [0,0] #move device to origin
qp(D)

D.remove(c)
qp(D)
ic = D << ic
qp(D)
mystyle = {(0.01, 0): {'fill': '#CC00FF','stroke': 'black'}}
D.write_svg('Nanobeam.svg', style=mystyle)

obj_width = D.ymax-D.ymin #calculate total height of cell
print(obj_width)

pad = Device()
pad_ref = pad.add_array(D, columns = 1, rows = 6, spacing = [0,obj_width])
pad.center = [0,0]

# add label to pad
label = Device()
T = pg.text('1', layer = 0, size = 0.5)
label << pg.invert(T, border = 0.15)
label.align(elements = 'all', alignment = 'x')
label.align(elements = 'all', alignment = 'y')
label.center = [0,0]
label.movex(pad.xmin-0.5)
label.movey(pad.ymin-0.5)
pad << label
qp(pad)

# add pad to full design
samples.append(pad)
# Out:
# 1.5439999999999987

# %%
DIR = '/Users/aaronday/Documents/Python/Research/GDS/SiCavityGDS/'
file_name = 'SiGcenterCavity_design2.gds'

D = Device() #create blank device and add unit cell to it
c = pg.import_gds(DIR+file_name, cellname = None, flatten = False)
qp(c) #plot 1
ic = pg.invert(c,border=0)
qp(ic) #plot 2 
h = c.ymax-c.ymin
w = c.xmax-c.xmin
#print(h)
#print(w)

c.add_port(name='N', midpoint= [0,h/2], width = w, orientation = 90)
c.add_port(name='S', midpoint= [0,c.ymin], width = w, orientation = 270)
trenchT = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
trenchB = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
c = D << c

c.connect(port = 'N', destination = trenchT.ports['S']) #stack trench-waveguide-trench for unit cell
trenchB.connect(port = 'N', destination = c.ports['S'])

D.center = [0,0] #move device to origin
qp(D) #plot 3

D.remove(c)
qp(D) #plot 4
ic = D << ic
qp(D) #plot 5

obj_width = D.ymax-D.ymin #calculate total height of cell
print(obj_width)

pad = Device()
pad_ref = pad.add_array(D, columns = 1, rows = 6, spacing = [0,obj_width])
pad.center = [0,0]

# add label to pad
label = Device()
T = pg.text('2', layer = 0, size = 0.5)
label << pg.invert(T, border = 0.15)
label.align(elements = 'all', alignment = 'x')
label.align(elements = 'all', alignment = 'y')
label.center = [0,0]
label.movex(pad.xmin-0.5)
label.movey(pad.ymin-0.5)
pad << label
qp(pad) #plot 6

# add pad to full design
samples.append(pad)
# Out:
# 1.5599999999999987

# %%
DIR = '/Users/aaronday/Documents/Python/Research/GDS/SiCavityGDS/'
file_name = 'SiGcenterCavity_design3.gds'

D = Device() #create blank device and add unit cell to it
c = pg.import_gds(DIR+file_name, cellname = None, flatten = False)
qp(c)
ic = pg.invert(c,border=0)
qp(ic)
h = c.ymax-c.ymin
w = c.xmax-c.xmin
#print(h)
#print(w)

c.add_port(name='N', midpoint= [0,h/2], width = w, orientation = 90)
c.add_port(name='S', midpoint= [0,c.ymin], width = w, orientation = 270)
trenchT = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
trenchB = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
c = D << c

c.connect(port = 'N', destination = trenchT.ports['S']) #stack trench-waveguide-trench for unit cell
trenchB.connect(port = 'N', destination = c.ports['S'])

D.center = [0,0] #move device to origin
qp(D)

D.remove(c)
qp(D)
ic = D << ic
qp(D)

obj_width = D.ymax-D.ymin #calculate total height of cell
print(obj_width)

pad = Device()
pad_ref = pad.add_array(D, columns = 1, rows = 6, spacing = [0,obj_width])
pad.center = [0,0]

# add label to pad
label = Device()
T = pg.text('3', layer = 0, size = 0.5)
label << pg.invert(T, border = 0.15)
label.align(elements = 'all', alignment = 'x')
label.align(elements = 'all', alignment = 'y')
label.center = [0,0]
label.movex(pad.xmin-0.5)
label.movey(pad.ymin-0.5)
pad << label
qp(pad)

# add pad to full design
samples.append(pad)
# Out:
# 1.561999999999999

# %%
DIR = '/Users/aaronday/Documents/Python/Research/GDS/SiCavityGDS/'
file_name = 'SiGcenterCavity_design4.gds'

D = Device() #create blank device and add unit cell to it
c = pg.import_gds(DIR+file_name, cellname = None, flatten = False)
qp(c)
ic = pg.invert(c,border=0)
qp(ic)
h = c.ymax-c.ymin
w = c.xmax-c.xmin
#print(h)
#print(w)

c.add_port(name='N', midpoint= [0,h/2], width = w, orientation = 90)
c.add_port(name='S', midpoint= [0,c.ymin], width = w, orientation = 270)
trenchT = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
trenchB = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
c = D << c

c.connect(port = 'N', destination = trenchT.ports['S']) #stack trench-waveguide-trench for unit cell
trenchB.connect(port = 'N', destination = c.ports['S'])

D.center = [0,0] #move device to origin
qp(D)

D.remove(c)
qp(D)
ic = D << ic
qp(D)

obj_width = D.ymax-D.ymin #calculate total height of cell
print(obj_width)

pad = Device()
pad_ref = pad.add_array(D, columns = 1, rows = 6, spacing = [0,obj_width])
pad.center = [0,0]

# add label to pad
label = Device()
T = pg.text('4', layer = 0, size = 0.5)
label << pg.invert(T, border = 0.15)
label.align(elements = 'all', alignment = 'x')
label.align(elements = 'all', alignment = 'y')
label.center = [0,0]
label.movex(pad.xmin-0.5)
label.movey(pad.ymin-0.5)
pad << label
qp(pad)

# add pad to full design
samples.append(pad)
# Out:
# 1.5599999999999987

# %%
DIR = '/Users/aaronday/Documents/Python/Research/GDS/SiCavityGDS/'
file_name = 'SiGcenterCavity_design5.gds'

D = Device() #create blank device and add unit cell to it
c = pg.import_gds(DIR+file_name, cellname = None, flatten = False)
qp(c)
ic = pg.invert(c,border=0)
qp(ic)
h = c.ymax-c.ymin
w = c.xmax-c.xmin
#print(h)
#print(w)

c.add_port(name='N', midpoint= [0,h/2], width = w, orientation = 90)
c.add_port(name='S', midpoint= [0,c.ymin], width = w, orientation = 270)
trenchT = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
trenchB = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
c = D << c

c.connect(port = 'N', destination = trenchT.ports['S']) #stack trench-waveguide-trench for unit cell
trenchB.connect(port = 'N', destination = c.ports['S'])

D.center = [0,0] #move device to origin
qp(D)

D.remove(c)
qp(D)
ic = D << ic
qp(D)

obj_width = D.ymax-D.ymin #calculate total height of cell
print(obj_width)

pad = Device()
pad_ref = pad.add_array(D, columns = 1, rows = 6, spacing = [0,obj_width])
pad.center = [0,0]

# add label to pad
label = Device()
T = pg.text('5', layer = 0, size = 0.5)
label << pg.invert(T, border = 0.15)
label.align(elements = 'all', alignment = 'x')
label.align(elements = 'all', alignment = 'y')
label.center = [0,0]
label.movex(pad.xmin-0.5)
label.movey(pad.ymin-0.5)
pad << label
qp(pad)

# add pad to full design
samples.append(pad)
# Out:
# 1.5879999999999987

# %%
DIR = '/Users/aaronday/Documents/Python/Research/GDS/SiCavityGDS/'
file_name = 'SiGcenterCavity_design6.gds'

D = Device() #create blank device and add unit cell to it
c = pg.import_gds(DIR+file_name, cellname = None, flatten = False)
qp(c)
ic = pg.invert(c,border=0)
qp(ic)
h = c.ymax-c.ymin
w = c.xmax-c.xmin
#print(h)
#print(w)

c.add_port(name='N', midpoint= [0,h/2], width = w, orientation = 90)
c.add_port(name='S', midpoint= [0,c.ymin], width = w, orientation = 270)
trenchT = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
trenchB = D << pg.compass([10,500e-3]) #define rectangular trench using compass labels for ports
c = D << c

c.connect(port = 'N', destination = trenchT.ports['S']) #stack trench-waveguide-trench for unit cell
trenchB.connect(port = 'N', destination = c.ports['S'])

D.center = [0,0] #move device to origin
qp(D)

D.remove(c)
qp(D)
ic = D << ic
qp(D)

obj_width = D.ymax-D.ymin #calculate total height of cell
print(obj_width)

pad = Device()
pad_ref = pad.add_array(D, columns = 1, rows = 6, spacing = [0,obj_width])
pad.center = [0,0]

# add label to pad
label = Device()
T = pg.text('6', layer = 0, size = 0.5)
label << pg.invert(T, border = 0.15)
label.align(elements = 'all', alignment = 'x')
label.align(elements = 'all', alignment = 'y')
label.center = [0,0]
label.movex(pad.xmin-0.5)
label.movey(pad.ymin-0.5)
pad << label
qp(pad)

# add pad to full design
samples.append(pad)
# Out:
# 1.5599999999999987

# %%
Grid = pg.grid(samples,
            spacing = (3,3),
            separation = True,
            shape = (2,3),
            align_x = 'x',
            align_y = 'y',
            edge_x = 'x',
            edge_y = 'ymax')

Grid.center = [0,0]
qp(Grid)

#Grid.write_gds('SiGcenterCavityGridRun1.gds')

#mystyle = {(0.01, 0): {'fill': '#CC00FF','stroke': 'black'}}
#Grid.write_svg('main.svg', style=mystyle)
#Grid.write_svg('SiGcenterGridRun1.svg')
